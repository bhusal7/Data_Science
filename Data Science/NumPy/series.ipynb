# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [1,2,3]
arr= np.array([1,2,3])
dic = {1:10, 2:20, 3:30}

# %%
pd.Series(my_list)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(arr)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(dic)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
pd.Series(my_list, index=labels)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(my_list, index=arr)
# Out:
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(dic, index=labels)
# Out:
# a   NaN
# b   NaN
# c   NaN
# dtype: float64

# %%
# Data Frames

# %%
people = {
    "Name": ["Ram", "Shyam", "Hari", "Sita"],
    "Age": [20, 22, 21, 23],
    "City": ["Butwal", "Kathmandu", "Pokhara", "Chitwan"],
    "Salary": [25000, 30000, 28000, 35000]
}

print(people)
# Out:
# {'Name': ['Ram', 'Shyam', 'Hari', 'Sita'], 'Age': [20, 22, 21, 23], 'City': ['Butwal', 'Kathmandu', 'Pokhara', 'Chitwan'], 'Salary': [25000, 30000, 28000, 35000]}

# %%
pd.DataFrame(people)
# Out:
#     Name  Age       City  Salary
# 0    Ram   20     Butwal   25000
# 1  Shyam   22  Kathmandu   30000
# 2   Hari   21    Pokhara   28000
# 3   Sita   23    Chitwan   35000

# %%
d_list = [
    ["Ram", 20, "Butwal", 25000],
    ["Shyam", 22, "Kathmandu", 30000],
    ["Hari", 21, "Pokhara", 28000],
    ["Sita", 23, "Chitwan", 35000]
]

print(people)
# Out:
# {'Name': ['Ram', 'Shyam', 'Hari', 'Sita'], 'Age': [20, 22, 21, 23], 'City': ['Butwal', 'Kathmandu', 'Pokhara', 'Chitwan'], 'Salary': [25000, 30000, 28000, 35000]}

# %%
pd.DataFrame(d_list)
# Out:
#        0   1          2      3
# 0    Ram  20     Butwal  25000
# 1  Shyam  22  Kathmandu  30000
# 2   Hari  21    Pokhara  28000
# 3   Sita  23    Chitwan  35000

# %%
import numpy as np

peo = np.array([
    ["Ram", 20, "Butwal", 25000],
    ["Shyam", 22, "Kathmandu", 30000],
    ["Hari", 21, "Pokhara", 28000],
    ["Sita", 23, "Chitwan", 35000]
])

print(peo)
# Out:
# [['Ram' '20' 'Butwal' '25000']
#  ['Shyam' '22' 'Kathmandu' '30000']
#  ['Hari' '21' 'Pokhara' '28000']
#  ['Sita' '23' 'Chitwan' '35000']]

# %%
pd.DataFrame(peo)
# Out:
#        0   1          2      3
# 0    Ram  20     Butwal  25000
# 1  Shyam  22  Kathmandu  30000
# 2   Hari  21    Pokhara  28000
# 3   Sita  23    Chitwan  35000

# %%
columns = ['Name','Age','City','Salary']
columns
# Out:
# ['Name', 'Age', 'City', 'Salary']

# %%
col=pd.DataFrame(peo, columns=columns)
col
# Out:
#     Name Age       City Salary
# 0    Ram  20     Butwal  25000
# 1  Shyam  22  Kathmandu  30000
# 2   Hari  21    Pokhara  28000
# 3   Sita  23    Chitwan  35000

# %%
# selection and indexing of columns

# %%
col
# Out:
#     Name Age       City Salary
# 0    Ram  20     Butwal  25000
# 1  Shyam  22  Kathmandu  30000
# 2   Hari  21    Pokhara  28000
# 3   Sita  23    Chitwan  35000

# %%
col['Name']
# Out:
# 0      Ram
# 1    Shyam
# 2     Hari
# 3     Sita
# Name: Name, dtype: object

# %%
col['City']
# Out:
# 0       Butwal
# 1    Kathmandu
# 2      Pokhara
# 3      Chitwan
# Name: City, dtype: object

# %%
col[['Age','Salary']]
# Out:
#   Age Salary
# 0  20  25000
# 1  22  30000
# 2  21  28000
# 3  23  35000

# %%
col["City"]
# Out:
# 0       Butwal
# 1    Kathmandu
# 2      Pokhara
# 3      Chitwan
# Name: City, dtype: object

# %%
col[['Name','Salary']]
# Out:
#     Name Salary
# 0    Ram  25000
# 1  Shyam  30000
# 2   Hari  28000
# 3   Sita  35000

# %%
col
# Out:
#     Name Age       City Salary
# 0    Ram  20     Butwal  25000
# 1  Shyam  22  Kathmandu  30000
# 2   Hari  21    Pokhara  28000
# 3   Sita  23    Chitwan  35000

# %%
#creating new column
col['Post'] = ["Doctor","Pilot","Sadhu","Brahmachari"]
col
# Out:
#     Name Age       City Salary         Post
# 0    Ram  20     Butwal  25000       Doctor
# 1  Shyam  22  Kathmandu  30000        Pilot
# 2   Hari  21    Pokhara  28000        Sadhu
# 3   Sita  23    Chitwan  35000  Brahmachari

# %%
# removing column

# %%
col.drop('Salary', axis=1)
# Out:
#     Name Age       City         Post
# 0    Ram  20     Butwal       Doctor
# 1  Shyam  22  Kathmandu        Pilot
# 2   Hari  21    Pokhara        Sadhu
# 3   Sita  23    Chitwan  Brahmachari

# %%
col.drop('Salary', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 col.drop('Salary', axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
col
# Out:
#     Name Age       City         Post
# 0    Ram  20     Butwal       Doctor
# 1  Shyam  22  Kathmandu        Pilot
# 2   Hari  21    Pokhara        Sadhu
# 3   Sita  23    Chitwan  Brahmachari

# %%
ar = np.array([
    [1, "Ram", 20, "Butwal", 25000],
    [2, "Shyam", 22, "Kathmandu", 30000],
    [3, "Hari", 21, "Pokhara", 28000],
    [4, "Sita", 23, "Chitwan", 35000]
])

column = ['S.N','Name','Age','City','Salary']

# %%
df =pd.DataFrame(ar,columns=column)
print(df)
# Out:
#   S.N   Name Age       City Salary
# 0   1    Ram  20     Butwal  25000
# 1   2  Shyam  22  Kathmandu  30000
# 2   3   Hari  21    Pokhara  28000
# 3   4   Sita  23    Chitwan  35000

# %%
df['paad'] = ['sanyas','sadhu','rishi','muni']
print(df)
# Out:
#   S.N   Name Age       City Salary    paad
# 0   1    Ram  20     Butwal  25000  sanyas
# 1   2  Shyam  22  Kathmandu  30000   sadhu
# 2   3   Hari  21    Pokhara  28000   rishi
# 3   4   Sita  23    Chitwan  35000    muni

# %%
df.drop(['paad','Age'], axis=1, inplace= True, errors='ignore')
print(df)
# Out:
#   S.N   Name       City Salary
# 0   1    Ram     Butwal  25000
# 1   2  Shyam  Kathmandu  30000
# 2   3   Hari    Pokhara  28000
# 3   4   Sita    Chitwan  35000

# %%
df
# Out:
#   S.N   Name Age       City Salary
# 0   1    Ram  20     Butwal  25000
# 1   2  Shyam  22  Kathmandu  30000
# 2   3   Hari  21    Pokhara  28000
# 3   4   Sita  23    Chitwan  35000

# %%
df.drop(columns=['paad','Age'], inplace=True, errors= 'ignore')
df
# Out:
#   S.N   Name       City Salary
# 0   1    Ram     Butwal  25000
# 1   2  Shyam  Kathmandu  30000
# 2   3   Hari    Pokhara  28000
# 3   4   Sita    Chitwan  35000

# %%
df.drop(1, axis=0)
# Out:
#   S.N  Name     City Salary
# 0   1   Ram   Butwal  25000
# 2   3  Hari  Pokhara  28000
# 3   4  Sita  Chitwan  35000

# %%
# selectiong row

# %%
df
# Out:
#   S.N   Name       City Salary
# 0   1    Ram     Butwal  25000
# 1   2  Shyam  Kathmandu  30000
# 2   3   Hari    Pokhara  28000
# 3   4   Sita    Chitwan  35000

# %%
df.loc[[0,1]]
# Out:
#   S.N   Name       City Salary
# 0   1    Ram     Butwal  25000
# 1   2  Shyam  Kathmandu  30000

# %%
# selection substes of rows and colomns

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#         City Salary
# 0     Butwal  25000
# 1  Kathmandu  30000

# %%
df
# Out:
#   S.N   Name       City Salary
# 0   1    Ram     Butwal  25000
# 1   2  Shyam  Kathmandu  30000
# 2   3   Hari    Pokhara  28000
# 3   4   Sita    Chitwan  35000

# %%
df.loc[[2,3]][['Name','City']]
# Out:
#    Name     City
# 2  Hari  Pokhara
# 3  Sita  Chitwan

# %%
#Conditional selection
 # select age > 20

# %%
col
# Out:
#     Name Age       City
# 0    Ram  20     Butwal
# 1  Shyam  22  Kathmandu
# 2   Hari  21    Pokhara
# 3   Sita  23    Chitwan

# %%
col[col['Age'] > '20']
# Out:
#     Name Age       City
# 1  Shyam  22  Kathmandu
# 2   Hari  21    Pokhara
# 3   Sita  23    Chitwan

# %%
col[(col['Age'] > "20") & (col['City'] == 'Chitwan')]
# Out:
#    Name Age     City
# 3  Sita  23  Chitwan
